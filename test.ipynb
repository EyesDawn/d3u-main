# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# # ===== 示例数据 =====
np.random.seed(0)
time = np.arange(0, 200)
data = np.sin(time / 10) + np.random.normal(0, 0.3, size=len(time))  # 一段时序数据

# # ===== 参数设置 =====
window_size = 10  # 滑动窗口大小

# # ===== 计算滑动窗口均值和标准差 =====
# df = pd.DataFrame({'data': data})
# rolling_mean = df['data'].rolling(window=window_size, center=True).mean()
# rolling_std = df['data'].rolling(window=window_size, center=True).std()  # 标准差

# # ===== 绘图 =====
plt.figure(figsize=(10, 5))
plt.plot(time, data, color='gray', alpha=0.3, label='Raw data')  # 原始数据
# plt.plot(time, rolling_mean, color='blue', label='Rolling mean')

# # 用阴影表示方差（mean ± std）
# plt.fill_between(time,
#                  rolling_mean - rolling_std,
#                  rolling_mean + rolling_std,
#                  color='blue', alpha=0.2, label='±1 Std')

# plt.xlabel('Time')
# plt.ylabel('Value')
# plt.title(f'Sliding Window Mean and Variance (window={window_size})')
# plt.legend()
# plt.grid(True)
# plt.tight_layout()
plt.show()
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
